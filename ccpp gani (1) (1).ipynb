# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Folds5x2_pp.csv")

# %%
data.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %%
data.isnull().any()
# Out:
# AT    False
# V     False
# AP    False
# RH    False
# PE    False
# dtype: bool

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.barplot(x='AT',y='V',data=data)
# Out:
# <AxesSubplot:xlabel='AT', ylabel='V'>

# %%
sns.scatterplot(x='AP',y='V',data=data)
# Out:
# <AxesSubplot:xlabel='AP', ylabel='V'>

# %%
plt.scatter(data['RH'],data['V'],color='blue')

# %%
sns.boxplot(x='PE',y='V',data=data)
# Out:
# <AxesSubplot:xlabel='PE', ylabel='V'>

# %%
data.describe()
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
data1=data

# %%
data1.describe()
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
x=data1.iloc[:,0:5]

# %%
x
# Out:
#          AT      V       AP     RH      PE
# 0      8.34  40.77  1010.84  90.01  480.48
# 1     23.64  58.49  1011.40  74.20  445.75
# 2     29.74  56.90  1007.15  41.91  438.76
# 3     19.07  49.69  1007.22  76.79  453.09
# 4     11.80  40.66  1017.13  97.20  464.43
# ...     ...    ...      ...    ...     ...
# 9563  15.12  48.92  1011.80  72.93  462.59
# 9564  33.41  77.95  1010.30  59.72  432.90
# 9565  15.99  43.34  1014.20  78.66  465.96
# 9566  17.65  59.87  1018.58  94.65  450.93
# 9567  23.68  51.30  1011.86  71.24  451.67
#
# [9568 rows x 5 columns]

# %%
x.drop('V',axis=1,inplace=True)
# Out:
# C:\Users\Ganesh\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
x
# Out:
#          AT       AP     RH      PE
# 0      8.34  1010.84  90.01  480.48
# 1     23.64  1011.40  74.20  445.75
# 2     29.74  1007.15  41.91  438.76
# 3     19.07  1007.22  76.79  453.09
# 4     11.80  1017.13  97.20  464.43
# ...     ...      ...    ...     ...
# 9563  15.12  1011.80  72.93  462.59
# 9564  33.41  1010.30  59.72  432.90
# 9565  15.99  1014.20  78.66  465.96
# 9566  17.65  1018.58  94.65  450.93
# 9567  23.68  1011.86  71.24  451.67
#
# [9568 rows x 4 columns]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.corr()
# Out:
#           AT        AP        RH        PE
# AT  1.000000 -0.507549 -0.542535 -0.948128
# AP -0.507549  1.000000  0.099574  0.518429
# RH -0.542535  0.099574  1.000000  0.389794
# PE -0.948128  0.518429  0.389794  1.000000

# %%
x=x.values

# %%
x
# Out:
# array([[   8.34, 1010.84,   90.01,  480.48],
#        [  23.64, 1011.4 ,   74.2 ,  445.75],
#        [  29.74, 1007.15,   41.91,  438.76],
#        ...,
#        [  15.99, 1014.2 ,   78.66,  465.96],
#        [  17.65, 1018.58,   94.65,  450.93],
#        [  23.68, 1011.86,   71.24,  451.67]])

# %%
y=data.iloc[:,1:2]

# %%
y
# Out:
#           V
# 0     40.77
# 1     58.49
# 2     56.90
# 3     49.69
# 4     40.66
# ...     ...
# 9563  48.92
# 9564  77.95
# 9565  43.34
# 9566  59.87
# 9567  51.30
#
# [9568 rows x 1 columns]

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
y=y.values

# %%
y
# Out:
# array([[40.77],
#        [58.49],
#        [56.9 ],
#        ...,
#        [43.34],
#        [59.87],
#        [51.3 ]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[-1.51786152, -0.40735691,  1.14394435,  1.53022576],
#        [ 0.5352555 , -0.31305658,  0.06103098, -0.50480238],
#        [ 1.35381849, -1.02872873, -2.15068773, -0.91438621],
#        ...,
#        [-0.49130301,  0.15844507,  0.36652077,  0.67941642],
#        [-0.26854652,  0.89600837,  1.46176333, -0.20127673],
#        [ 0.54062312, -0.2355956 , -0.14171561, -0.15791592]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[-0.60402316,  0.51880705, -0.73420142,  0.42393923],
#        [ 0.76472152,  0.34199393,  0.31035449, -1.09603284],
#        [-0.17058735,  1.17217362, -0.34103742, -0.18018228],
#        ...,
#        [ 0.52317834, -0.23727953,  1.00421359, -0.96595042],
#        [ 0.1461026 ,  0.36556901,  0.31309431, -0.26104433],
#        [-1.23337733,  1.24458281,  1.29668925,  1.13646276]])

# %%
x_train.shape,x_test.shape
# Out:
# ((7654, 4), (1914, 4))

# %%
y_train.shape,y_test.shape
# Out:
# ((7654, 1), (1914, 1))

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
y_test
# Out:
# array([[69.13],
#        [57.5 ],
#        [57.32],
#        ...,
#        [49.21],
#        [60.84],
#        [71.64]])

# %%
y_pred_lr=lr.predict(x_test)
y_pred_lr
# Out:
# array([[70.65710354],
#        [58.13375904],
#        [60.09062711],
#        ...,
#        [53.684039  ],
#        [61.29269717],
#        [66.82493296]])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_lr)
# Out:
# 0.775772088661744

# %%
import pickle
pickle.dump(lr,open('ccpp.pkl','wb'))
